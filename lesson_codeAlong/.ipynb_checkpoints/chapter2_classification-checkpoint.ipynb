# %% [markdown]
# # Neural Network Classification

# %%
import sklearn
from sklearn.datasets import make_circles

# %%
n_samples=1000
X,y = make_circles(n_samples,noise=0.03,random_state=42)

# %%
import pandas as pd
circles = pd.DataFrame({"X1":X[:, 0],
                        "X2":X[:, 1],
                        "label":y})
circles.head(10)
# Out:
#          X1        X2  label
# 0  0.754246  0.231481      1
# 1 -0.756159  0.153259      1
# 2 -0.815392  0.173282      1
# 3 -0.393731  0.692883      1
# 4  0.442208 -0.896723      0
# 5 -0.479646  0.676435      1
# 6 -0.013648  0.803349      1
# 7  0.771513  0.147760      1
# 8 -0.169322 -0.793456      1
# 9 -0.121486  1.021509      0

# %%
import matplotlib.pyplot as plt
plt.scatter(x=circles['X1'],y=circles['X2'],c=circles['label'],cmap=plt.cm.RdYlGn)

# %% [markdown]
# ### Turn data into tensors

# %%
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
import torch
torch.__version__
# Out:
# '2.2.1+cu121'

# %%
type(X)
# Out:
# numpy.ndarray

# %%
Xt = torch.from_numpy(X).type(torch.float)
yt=torch.from_numpy(y).type(torch.float)

# %% [markdown]
# ### Splitting data into training and test test

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(Xt,yt,train_size = 0.8,random_state=42)

# %%
len(X_train),len(X_test),len(y_train),len(y_test)
# Out:
# (800, 200, 800, 200)

# %%
X_train.shape
# Out:
# torch.Size([800, 2])

# %% [markdown]
# ### Building a model to classify blue and red dots

# %%
import torch
from torch import nn
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
#Model class which subclasses nn.Module
class CircleModel(nn.Module):
    def __init__(self):
        super().__init__()
        #creating layers for NN
        self.layer_1=nn.Linear(in_features=2,out_features =8) #taking 2 input features and upscaling to 8 features for hidden layer 
        self.layer_2=nn.Linear(in_features=8,out_features=1) #8 hidden layer features become output layer's 1 feature

    def forward(self,x):
            return self.layer_2(self.layer_1(x)) #x->layer1->layer2->output

# %%
torch.manual_seed(42)
model0 = CircleModel().to(device)
model0
# Out:
# CircleModel(
#   (layer_1): Linear(in_features=2, out_features=8, bias=True)
#   (layer_2): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
next(model0.parameters()).device
# Out:
# device(type='cuda', index=0)

# %%
model0.state_dict()
# Out:
# OrderedDict([('layer_1.weight',
#               tensor([[ 0.5406,  0.5869],
#                       [-0.1657,  0.6496],
#                       [-0.1549,  0.1427],
#                       [-0.3443,  0.4153],
#                       [ 0.6233, -0.5188],
#                       [ 0.6146,  0.1323],
#                       [ 0.5224,  0.0958],
#                       [ 0.3410, -0.0998]], device='cuda:0')),
#              ('layer_1.bias',
#               tensor([ 0.5451,  0.1045, -0.3301,  0.1802, -0.3258, -0.0829, -0.2872,  0.4691],
#                      device='cuda:0')),
#              ('layer_2.weight',
#               tensor([[-0.2791, -0.1630, -0.0998, -0.2126,  0.0334, -0.3492,  0.3193, -0.3003]],
#                      device='cuda:0')),
#              ('layer_2.bias', tensor([0.2730], device='cuda:0'))])

# %% [markdown]
# ### Creating model using nn.Sequential
# Simpler than class(nn.Module) but less functionality, good for simple NNs

# %%
model1 = nn.Sequential (
    nn.Linear(in_features=2,out_features=8),
    nn.Linear(in_features=8,out_features=1)
).to(device)

# %%
model1
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=8, bias=True)
#   (1): Linear(in_features=8, out_features=1, bias=True)
# )

# %% [markdown]
# ### Inference

# %%
with torch.inference_mode():
    untrained_preds = model0(X_test.to(device))
untrained_preds[:10]
# Out:
# tensor([[-0.3104],
#         [-0.4788],
#         [ 0.1177],
#         [-0.4316],
#         [ 0.0967],
#         [-0.0059],
#         [-0.4633],
#         [-0.3526],
#         [ 0.1179],
#         [-0.4903]], device='cuda:0')

# %% [markdown]
# ### Loss function and optimizer

# %%
loss_fn = torch.nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(params=model0.parameters(),lr=0.1)

# %% [markdown]
# ### Accuracy Function

# %%
def accuracy_fn(y_true,y_pred):
    correct = torch.eq(y_true,y_pred).sum().item()
    return (correct/len(y_pred)) * 100

# %% [markdown]
# ## Training loop

# %% [markdown]
# #### Raw logits-> prediction probabiliies -> prediction labels

# %%
#model outputs are raw logits
model0.eval()
with torch.inference_mode():
    y_logits = model0(X_test.to(device))
y_logits[:5]
# Out:
# tensor([[-0.3104],
#         [-0.4788],
#         [ 0.1177],
#         [-0.4316],
#         [ 0.0967]], device='cuda:0')

# %%
y_test[:5]
# Out:
# tensor([1., 0., 1., 0., 1.])

# %% [markdown]
# #### Need to make y_logits into same format as y_test as y_logit is model0's y output when we feed it x_test
# We do this by passing it through an activation function, like sigmoid

# %%
y_pred_probs = torch.sigmoid(y_logits)
y_pred_probs[:5]
# Out:
# tensor([[0.4230],
#         [0.3825],
#         [0.5294],
#         [0.3937],
#         [0.5242]], device='cuda:0')

# %%
#rounding off prediction probability to get labels
torch.round(y_pred_probs)[:5]
# Out:
# tensor([[0.],
#         [0.],
#         [1.],
#         [0.],
#         [1.]], device='cuda:0')

# %% [markdown]
# ### Putting it all together:

# %%
y_pred_labels = torch.round(torch.sigmoid(model0(X_test.to(device))))
y_pred_labels[:5]
# Out:
# tensor([[0.],
#         [0.],
#         [1.],
#         [0.],
#         [1.]], device='cuda:0', grad_fn=<SliceBackward0>)

# %% [markdown]
# ### Testing and training loop

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)

epochs = 100
X_train, y_train =X_train.to(device), y_train.to(device)
X_test, y_test =X_test.to(device), y_test.to(device) 

for epoch in range(epochs):
    model0.train()
    #1. Forward pass
    y_logits = model0(X_train).squeeze()
    y_pred = torch.round(torch.sigmoid(y_logits)) #turn logits-> pred probs

    #2.Loss/Accuracy calculation
    loss = loss_fn(y_logits,y_train) #BCEwithLogits expects logits 
    acc = accuracy_fn(y_train,y_pred)

    #3. Optimizer zero grad
    optimizer.zero_grad()
    #4. Loss backwards(Backpropagation)
    loss.backward()
    #5. Optimizer step
    optimizer.step()

    model0.eval()
    with torch.inference_mode():
         #1. Forward pass
        test_logits = model0(X_test).squeeze()
        test_pred = torch.round(torch.sigmoid(test_logits))

        #2.Loss/Accuracy calculation
        test_loss = loss_fn(test_logits,y_test)
        test_acc = accuracy_fn(y_test,test_pred)

    #Print out whats happening
    if epoch%10==0:
        print(f"Epoch: {epoch}| Loss:{loss:.3f}| Acc:{acc:.2f}%| Test Loss:{test_loss:.3f}| Test Acc:{test_acc:.2f}%")
# Out:
# Epoch: 0| Loss:0.694| Acc:49.75%| Test Loss:0.692| Test Acc:54.50%
# Epoch: 10| Loss:0.693| Acc:50.12%| Test Loss:0.692| Test Acc:54.50%
# Epoch: 20| Loss:0.693| Acc:50.75%| Test Loss:0.693| Test Acc:54.00%
# Epoch: 30| Loss:0.693| Acc:53.00%| Test Loss:0.693| Test Acc:53.50%
# Epoch: 40| Loss:0.693| Acc:50.00%| Test Loss:0.693| Test Acc:50.00%
# Epoch: 50| Loss:0.693| Acc:55.12%| Test Loss:0.693| Test Acc:49.50%
# Epoch: 60| Loss:0.693| Acc:52.00%| Test Loss:0.693| Test Acc:47.00%
# Epoch: 70| Loss:0.693| Acc:51.75%| Test Loss:0.694| Test Acc:46.50%
# Epoch: 80| Loss:0.693| Acc:51.62%| Test Loss:0.694| Test Acc:47.00%
# Epoch: 90| Loss:0.693| Acc:51.50%| Test Loss:0.694| Test Acc:47.00%

# %% [markdown]
# ## Why isn't our model learning?

# %%
import requests
from pathlib import Path

#Downloading helper functions from learnpytorch repo

if Path("helper_functions.py").is_file():
    print("Already downloaded.")
else:
    print("Downloading...")
    request = requests.get("https://raw.githubusercontent.com/mrdbourke/pytorch-deep-learning/main/helper_functions.py")
    with open("helper_functions.py","wb") as f:
        f.write(request.content)
# Out:
# Downloading...

# %%
from helper_functions import plot_predictions,plot_decision_boundary

plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.title("Train")
plot_decision_boundary(model0,X_train,y_train)
plt.subplot(1,2,2)
plt.title("Test")
plot_decision_boundary(model0,X_test,y_test)

# %% [markdown]
# #### As out data plot is circular, we need to use non linear activation parameters. We're using linear activations here so it cannot fit our data properly

# %% [markdown]
# ### Non Linear Model

# %%
import torch 
from torch import nn

class CircleModelv2(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer1 = nn.Linear(in_features=2,out_features=16)
        self.layer2 = nn.Linear(in_features=16,out_features=16)
        self.layer3=  nn.Linear(in_features=16,out_features=1)
        self.relu = nn.ReLU() #non - linear activations functions

    def forward(self,x):
        return self.layer3(self.relu(self.layer2(self.relu(self.layer1(x)))))

# %%
model2 = CircleModelv2().to(device)
model2
# Out:
# CircleModelv2(
#   (layer1): Linear(in_features=2, out_features=16, bias=True)
#   (layer2): Linear(in_features=16, out_features=16, bias=True)
#   (layer3): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
loss_fn = torch.nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(params=model2.parameters(),lr=0.1)

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)

epochs = 1000
X_train, y_train =X_train.to(device), y_train.to(device)
X_test, y_test =X_test.to(device), y_test.to(device) 

for epoch in range(epochs):
    model2.train()
    #1. Forward pass
    y_logits = model2(X_train).squeeze()
    y_pred = torch.round(torch.sigmoid(y_logits)) #turn logits-> pred probs

    #2.Loss/Accuracy calculation
    loss = loss_fn(y_logits,y_train) #BCEwithLogits expects logits 
    acc = accuracy_fn(y_train,y_pred)

    #3. Optimizer zero grad
    optimizer.zero_grad()
    #4. Loss backwards(Backpropagation)
    loss.backward()
    #5. Optimizer step
    optimizer.step()

    model2.eval()
    with torch.inference_mode():
         #1. Forward pass
        test_logits = model2(X_test).squeeze()
        test_pred = torch.round(torch.sigmoid(test_logits))

        #2.Loss/Accuracy calculation
        test_loss = loss_fn(test_logits,y_test)
        test_acc = accuracy_fn(y_test,test_pred)

    #Print out whats happening
    if epoch%100==0:
        print(f"Epoch: {epoch}| Loss:{loss:.3f}| Acc:{acc:.3f}%| Test Loss:{test_loss:.3f}| Test Acc:{test_acc:.3f}%")
# Out:
# Epoch: 0| Loss:0.482| Acc:99.250%| Test Loss:0.517| Test Acc:97.000%
# Epoch: 100| Loss:0.363| Acc:99.750%| Test Loss:0.409| Test Acc:99.000%
# Epoch: 200| Loss:0.237| Acc:100.000%| Test Loss:0.286| Test Acc:99.500%
# Epoch: 300| Loss:0.145| Acc:100.000%| Test Loss:0.191| Test Acc:100.000%
# Epoch: 400| Loss:0.094| Acc:100.000%| Test Loss:0.134| Test Acc:100.000%
# Epoch: 500| Loss:0.064| Acc:100.000%| Test Loss:0.098| Test Acc:100.000%
# Epoch: 600| Loss:0.046| Acc:100.000%| Test Loss:0.077| Test Acc:100.000%
# Epoch: 700| Loss:0.036| Acc:100.000%| Test Loss:0.063| Test Acc:100.000%
# Epoch: 800| Loss:0.029| Acc:100.000%| Test Loss:0.054| Test Acc:100.000%
# Epoch: 900| Loss:0.024| Acc:100.000%| Test Loss:0.047| Test Acc:100.000%

# %%
plt.figure(figsize=(12,12))
plt.subplot(2,2,1)
plt.title("Train")
plot_decision_boundary(model2,X_train,y_train)
plt.subplot(2,2,2)
plt.title("Test")
plot_decision_boundary(model2,X_test,y_test)
plt.subplot(2,2,3)
plt.title("Train")
plot_decision_boundary(model0,X_train,y_train)
plt.subplot(2,2,4)
plt.title("Test")
plot_decision_boundary(model0,X_test,y_test)

# %% [markdown]
# ## Multiclass classification

# %%
import torch
from torch import nn 
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split

classes=4
features=2
seed=42

# %%
#Creating dataset
X_blob, y_blob  = make_blobs(n_samples=1000,
                             n_features=features,
                             centers=classes,
                             cluster_std=1.5,
                             random_state=seed)
#Turning data into tensors
X_blob = torch.from_numpy(X_blob).type(torch.float)
y_blob = torch.from_numpy(y_blob).type(torch.long)

#Test/Train split
X_train,X_test,y_train,y_test = train_test_split(X_blob,
                                                 y_blob,
                                                train_size=0.8,
                                                random_state=seed)

# %%
len(X_train),len(X_test),len(y_train),len(y_test)
# Out:
# (800, 200, 800, 200)

# %%
y_blob.shape
# Out:
# torch.Size([1000])

# %%
plt.figure(figsize=(10,7))
plt.scatter(X_blob[:,0],X_blob[:,1],c=y_blob,cmap=plt.cm.RdYlBu)

# %% [markdown]
# ### Building the model

# %%
class BlobModel(nn.Module):
    def __init__(self,in_features,out_features,hidden=8):
        super().__init__()
        self.linear_layer_stack = nn.Sequential(
            nn.Linear(in_features=in_features,out_features=hidden),
            nn.ReLU(),
            nn.Linear(in_features=hidden,out_features=hidden),
            nn.ReLU(),
            nn.Linear(in_features=hidden,out_features=out_features)
        )
    def forward(self,x):
        return self.linear_layer_stack(x)

model3 = BlobModel(in_features=2,out_features=4,hidden=8)

# %% [markdown]
# ### Loss func and Optimizer

# %%
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model3.parameters(),lr=0.1)

# %% [markdown]
# ### Making Predictions
# *  Model predictions ->logits,
# * Convert logits -> prediction % ->  labels
# * Select most label of highest % from output features

# %%
model3.eval()
with torch.inference_mode():
    logits = model3(X_test)
    pred_probs = torch.softmax(logits,dim=1)
    pred_label = torch.argmax(pred_probs,dim=1)
print(f"{logit[:5]},Min:{logit.min():.2f},Max:{logit.max():.2f}")
print(f"{pred_probs[:5]},Min:{pred_probs.min():.2f},Max:{pred_probs.max():.2f}")
print(pred_label[:10])
print(y_blob[:10])
# Out:
# tensor([[-0.7646, -0.7412, -1.5777, -1.1376],
#         [-0.0973, -0.9431, -0.5963, -0.1371],
#         [ 0.2528, -0.2379,  0.1882, -0.0066],
#         [-0.4134, -0.5204, -0.9303, -0.6963],
#         [-0.3118, -1.3736, -1.1991, -0.3834]]),Min:-2.15,Max:0.25
# tensor([[0.2979, 0.3062, 0.2190, 0.1769],
#         [0.2092, 0.2272, 0.3971, 0.1666],
#         [0.1989, 0.3577, 0.3329, 0.1105],
#         [0.3012, 0.3272, 0.2004, 0.1712],
#         [0.2832, 0.2280, 0.2874, 0.2014]]),Min:0.08,Max:0.52
# tensor([1, 2, 1, 1, 2, 2, 1, 2, 1, 2])
# tensor([3, 2, 2, 1, 1, 2, 1, 2, 2, 1])

# %% [markdown]
# ### Training and testing loop

# %%
torch.manual_seed = seed
torch.cuda.manual_seed = seed
epochs =1000

for epoch in range(epochs):
    ###Training
    model3.train()
    #1.forward pass
    logits = model3(X_train)
    y_preds =torch.softmax(logits,dim=1).argmax(dim=1)
    #2.calculate loss 
    loss = loss_fn(logits,y_train)
    acc = accuracy_fn(y_true=y_train,
                     y_pred=y_preds)
    #3.back propagation
    optimizer.zero_grad()
    loss.backward()
    #4.gradient descent 
    optimizer.step()

    ###Testing
    model3.eval()
    test_logits = model3(X_test)
    test_preds = torch.softmax(test_logits,dim=1).argmax(dim=1)
    test_loss =loss_fn(test_logits,y_test)
    test_acc = accuracy_fn(y_true=y_test,
                          y_pred=test_preds)
    #Print
    if epoch%10==0:
        print(f"Epoch:{epoch}| Loss:{loss:.3f}| Acc:{acc:.3f}| Test Loss:{test_loss:.3f}| Test Acc:{test_acc:.3f}")
# Out:
# Epoch:0| Loss:1.326| Acc:33.000| Test Loss:1.168| Test Acc:50.500
# Epoch:10| Loss:0.561| Acc:77.500| Test Loss:0.518| Test Acc:76.500
# Epoch:20| Loss:0.374| Acc:81.125| Test Loss:0.364| Test Acc:82.000
# Epoch:30| Loss:0.277| Acc:94.000| Test Loss:0.259| Test Acc:97.500
# Epoch:40| Loss:0.148| Acc:98.625| Test Loss:0.135| Test Acc:100.000
# Epoch:50| Loss:0.096| Acc:99.000| Test Loss:0.085| Test Acc:99.500
# Epoch:60| Loss:0.072| Acc:99.000| Test Loss:0.062| Test Acc:99.500
# Epoch:70| Loss:0.059| Acc:99.125| Test Loss:0.049| Test Acc:99.500
# Epoch:80| Loss:0.050| Acc:99.125| Test Loss:0.041| Test Acc:99.500
# Epoch:90| Loss:0.045| Acc:99.125| Test Loss:0.036| Test Acc:99.500
# Epoch:100| Loss:0.041| Acc:99.250| Test Loss:0.032| Test Acc:99.500
# Epoch:110| Loss:0.039| Acc:99.250| Test Loss:0.029| Test Acc:99.500
# Epoch:120| Loss:0.036| Acc:99.250| Test Loss:0.027| Test Acc:99.500
# Epoch:130| Loss:0.035| Acc:99.250| Test Loss:0.025| Test Acc:99.500
# Epoch:140| Loss:0.033| Acc:99.250| Test Loss:0.024| Test Acc:99.500
# Epoch:150| Loss:0.032| Acc:99.250| Test Loss:0.023| Test Acc:99.500
# Epoch:160| Loss:0.031| Acc:99.250| Test Loss:0.022| Test Acc:99.500
# Epoch:170| Loss:0.031| Acc:99.250| Test Loss:0.021| Test Acc:99.500
# Epoch:180| Loss:0.030| Acc:99.250| Test Loss:0.020| Test Acc:99.500
# Epoch:190| Loss:0.030| Acc:99.250| Test Loss:0.019| Test Acc:99.500
# Epoch:200| Loss:0.029| Acc:99.250| Test Loss:0.019| Test Acc:99.500
# Epoch:210| Loss:0.029| Acc:99.250| Test Loss:0.018| Test Acc:99.500
# Epoch:220| Loss:0.028| Acc:99.250| Test Loss:0.018| Test Acc:99.500
# Epoch:230| Loss:0.028| Acc:99.250| Test Loss:0.018| Test Acc:99.500
# Epoch:240| Loss:0.028| Acc:99.250| Test Loss:0.017| Test Acc:99.500
# Epoch:250| Loss:0.027| Acc:99.250| Test Loss:0.017| Test Acc:99.500
# Epoch:260| Loss:0.027| Acc:99.250| Test Loss:0.017| Test Acc:99.500
# Epoch:270| Loss:0.027| Acc:99.250| Test Loss:0.016| Test Acc:99.500
# Epoch:280| Loss:0.027| Acc:99.250| Test Loss:0.016| Test Acc:99.500
# Epoch:290| Loss:0.027| Acc:99.250| Test Loss:0.016| Test Acc:99.500
# Epoch:300| Loss:0.026| Acc:99.250| Test Loss:0.016| Test Acc:99.500
# Epoch:310| Loss:0.026| Acc:99.250| Test Loss:0.015| Test Acc:99.500
# Epoch:320| Loss:0.026| Acc:99.250| Test Loss:0.015| Test Acc:99.500
# Epoch:330| Loss:0.026| Acc:99.250| Test Loss:0.015| Test Acc:99.500
# Epoch:340| Loss:0.026| Acc:99.250| Test Loss:0.015| Test Acc:99.500
# Epoch:350| Loss:0.026| Acc:99.250| Test Loss:0.015| Test Acc:99.500
# Epoch:360| Loss:0.026| Acc:99.250| Test Loss:0.015| Test Acc:99.500
# Epoch:370| Loss:0.026| Acc:99.250| Test Loss:0.014| Test Acc:99.500
# Epoch:380| Loss:0.025| Acc:99.250| Test Loss:0.014| Test Acc:99.500
# Epoch:390| Loss:0.025| Acc:99.250| Test Loss:0.014| Test Acc:99.500
# Epoch:400| Loss:0.025| Acc:99.250| Test Loss:0.014| Test Acc:99.500
# Epoch:410| Loss:0.025| Acc:99.250| Test Loss:0.014| Test Acc:99.500
# Epoch:420| Loss:0.025| Acc:99.250| Test Loss:0.014| Test Acc:99.500
# Epoch:430| Loss:0.025| Acc:99.250| Test Loss:0.014| Test Acc:99.500
# Epoch:440| Loss:0.025| Acc:99.250| Test Loss:0.014| Test Acc:99.500
# Epoch:450| Loss:0.025| Acc:99.250| Test Loss:0.014| Test Acc:99.500
# Epoch:460| Loss:0.025| Acc:99.250| Test Loss:0.014| Test Acc:99.500
# Epoch:470| Loss:0.025| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:480| Loss:0.025| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:490| Loss:0.025| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:500| Loss:0.025| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:510| Loss:0.025| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:520| Loss:0.024| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:530| Loss:0.024| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:540| Loss:0.024| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:550| Loss:0.024| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:560| Loss:0.024| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:570| Loss:0.024| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:580| Loss:0.024| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:590| Loss:0.024| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:600| Loss:0.024| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:610| Loss:0.024| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:620| Loss:0.024| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:630| Loss:0.024| Acc:99.250| Test Loss:0.013| Test Acc:99.500
# Epoch:640| Loss:0.024| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:650| Loss:0.024| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:660| Loss:0.024| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:670| Loss:0.024| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:680| Loss:0.024| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:690| Loss:0.024| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:700| Loss:0.024| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:710| Loss:0.024| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:720| Loss:0.024| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:730| Loss:0.024| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:740| Loss:0.024| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:750| Loss:0.024| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:760| Loss:0.023| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:770| Loss:0.023| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:780| Loss:0.023| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:790| Loss:0.023| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:800| Loss:0.023| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:810| Loss:0.023| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:820| Loss:0.023| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:830| Loss:0.023| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:840| Loss:0.023| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:850| Loss:0.023| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:860| Loss:0.023| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:870| Loss:0.023| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:880| Loss:0.023| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:890| Loss:0.023| Acc:99.250| Test Loss:0.012| Test Acc:99.500
# Epoch:900| Loss:0.023| Acc:99.250| Test Loss:0.011| Test Acc:99.500
# Epoch:910| Loss:0.023| Acc:99.250| Test Loss:0.011| Test Acc:99.500
# Epoch:920| Loss:0.023| Acc:99.250| Test Loss:0.011| Test Acc:99.500
# Epoch:930| Loss:0.023| Acc:99.250| Test Loss:0.011| Test Acc:99.500
# Epoch:940| Loss:0.023| Acc:99.250| Test Loss:0.011| Test Acc:99.500
# Epoch:950| Loss:0.023| Acc:99.375| Test Loss:0.011| Test Acc:99.500
# Epoch:960| Loss:0.023| Acc:99.375| Test Loss:0.011| Test Acc:99.500
# Epoch:970| Loss:0.023| Acc:99.375| Test Loss:0.011| Test Acc:99.500
# Epoch:980| Loss:0.023| Acc:99.375| Test Loss:0.011| Test Acc:99.500
# Epoch:990| Loss:0.023| Acc:99.375| Test Loss:0.011| Test Acc:99.500

# %% [markdown]
# ### Visualize, Visualize, Visualize

# %%
from helper_functions import plot_predictions,plot_decision_boundary
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.title("Train")
plot_decision_boundary(model3,X_train,y_train)
plt.subplot(1,2,2)
plt.title("Test")
plot_decision_boundary(model3,X_test,y_test)
